# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib.pyplot as plt

# %%
x = smp.symbols('x')

# %%
y = x ** 3
z = x ** 2

# %%
y
# Out:
# x**2

# %%
display(y)
# Out:
# x**2

# %%
smp.plot(y, line_color='red')
smp.plot(z, line_color='b')
