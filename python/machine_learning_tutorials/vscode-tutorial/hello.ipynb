# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic.csv')

# %% [markdown]
# # Prepare the data

# %%
data.replace('?', np.nan, inplace=True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %% [markdown]
# # Train and evaluate a model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %% [markdown]
# # (Optional) Use a neural network

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 2s 3ms/step - loss: 0.6924 - accuracy: 0.5789
# Epoch 2/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6903 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6645 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6458 - accuracy: 0.5861
# Epoch 7/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6247 - accuracy: 0.5861
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6054 - accuracy: 0.5861
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5912 - accuracy: 0.5861
# Epoch 10/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.5861
# Epoch 11/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5745 - accuracy: 0.5861
# Epoch 12/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5693 - accuracy: 0.5861
# Epoch 13/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5653 - accuracy: 0.6388
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5620 - accuracy: 0.7835
# Epoch 15/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5591 - accuracy: 0.7811
# Epoch 16/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5560 - accuracy: 0.7811
# Epoch 17/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5539 - accuracy: 0.7883
# Epoch 18/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5512 - accuracy: 0.7883
# Epoch 19/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.7883
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5473 - accuracy: 0.7871
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5450 - accuracy: 0.7859
# Epoch 22/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5429 - accuracy: 0.7859
# Epoch 23/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5410 - accuracy: 0.7847
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7871
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.7859
# Epoch 26/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5354 - accuracy: 0.7859
# Epoch 27/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5337 - accuracy: 0.7895
# Epoch 28/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5323 - accuracy: 0.7931
# Epoch 29/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5307 - accuracy: 0.7895
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5291 - accuracy: 0.7907
# Epoch 31/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5277 - accuracy: 0.7931
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5265 - accuracy: 0.7919
# Epoch 33/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5251 - accuracy: 0.7895
# Epoch 34/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5238 - accuracy: 0.7907
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5225 - accuracy: 0.7955
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5211 - accuracy: 0.7990
# Epoch 37/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5199 - accuracy: 0.7967
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.8002
# Epoch 39/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5175 - accuracy: 0.8002
# Epoch 40/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.5164 - accuracy: 0.7978
# Epoch 41/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5153 - accuracy: 0.7967
# Epoch 42/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5143 - accuracy: 0.7967
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.8002
# Epoch 44/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5124 - accuracy: 0.7955
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5118 - accuracy: 0.7943
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5106 - accuracy: 0.7931
# Epoch 47/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5095 - accuracy: 0.7943
# Epoch 48/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.7943
# Epoch 49/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5078 - accuracy: 0.7931
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5071 - accuracy: 0.7919

# %%
y_pred = np.argmax(model.predict(X_test), axis=-1)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.6124401913875598
